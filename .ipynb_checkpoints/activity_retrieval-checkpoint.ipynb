# %% [markdown]
# ### Activity has 6 sub-categories, and Events, Starring, and Watching are completed
# - __Events__(usable)
# - Event Types & Payloads(to be confirmed)
# - Feeds(user-center)
# - Notifications(user-center)
# - __Starring__(usable)
# - __Watching__(no timestamp, no use)

# %%
import requests
import json
import time
from pymongo import MongoClient
import random

# %%
ACCESS_TOKEN = '251e9806e8f4838cc49d5536e50bb2923a17ab15'

# %%
def github_request(params, headers, per_page=30, page=1, show_head=False, show_body=False, is_write=False):
    """ Description: function to perform a github api request
        - params: a list of request parameters
        - headers: a dict of request headers
        - per_page: defalt 30 records per page, can go up to 100
        - page: default starts from page 1
        - show_head: default False, not show the response head
        - show_body: default False, not show the response body
        - is_write: default False, if write out to json file, default in current directory
        - return: a string of status code, and a json object of response
    """
    url = "https://api.github.com/" + '/'.join(params) + '?per_page={}&page={}'.format(per_page, page)
    print 'requesting: ' + url
    response = requests.get(url, headers=headers) # get response
    if show_body:
        # body
        print json.dumps(response.json(), indent=1)
        print '------------------------------------'
    if show_head:
        # header
        for (k,v) in response.headers.items():
            print k, "=>", v
        print '------------------------------------'
    file_name = '.'.join(params) + '.json'
    if is_write:
        with open(file_name, 'w') as jsonfile:
            json.dump(response.json(), jsonfile)
    print 'total records of this request: {}'.format(len(response.json()))
    return response.headers['Status'], response.json()

# %% [markdown]
# # Events(usable)
# https://developer.github.com/v3/activity/events/

# %% [markdown]
# __Events support pagination, however the per_page option is unsupported. The fixed page size is 30 items. Fetching up to ten pages is supported, for a total of 300 events.__
#
# __Only events created within the past 90 days will be included in timelines. Events older than 90 days will not be included (even if the total number of events in the timeline is less than 300).__

# %% [markdown]
# ### List repository events
# GET /repos/:owner/:repo/events

# %%
params = ['repos', 'Jubatus', 'jubakit', 'events']
headers = {'Authorization' : 'token {}'.format(ACCESS_TOKEN)}

# %%
status, result = github_request(params=params,headers=headers, per_page=100, page=1, is_write=False)
# Out:
# requesting: https://api.github.com/repos/Jubatus/jubakit/events?per_page=100&page=1
# total records of this request: 100

# %%
status
# Out:
# '200 OK'

# %% [markdown]
# # Starring(usable)
# https://developer.github.com/v3/activity/starring/
#
# __Wachers also has no query limit, can increase per_page to 100, with timestamp option__

# %% [markdown]
# ### List Stargazers
# __GET /repos/:owner/:repo/stargazers__
#
# You can also find out when stars were created by passing the following custom media type via the Accept header:
#
# __Accept: application/vnd.github.v3.star+json__

# %%
params = ['repos', 'Jubatus', 'jubatus', 'stargazers']
headers = {'Authorization' : 'token {}'.format(ACCESS_TOKEN),'Accept' : 'application/vnd.github.v3.star+json'}

# %%
status, result = github_request(params=params,headers=headers, per_page=100, page=2, is_write=False)
# Out:
# requesting: https://api.github.com/repos/Jubatus/jubatus/stargazers?per_page=100&page=2
# total records of this request: 100

# %%
status
# Out:
# '200 OK'

# %% [markdown]
# # Watching(no use)
# https://developer.github.com/v3/activity/watching/
#
# __No timestamp__

# %% [markdown]
# ### List watchers
# GET /repos/:owner/:repo/subscribers

# %%
params = ['repos', 'Jubatus', 'jubatus', 'subscribers']
headers = {'Authorization' : 'token {}'.format(ACCESS_TOKEN),'Accept' : 'application/vnd.github.v3.full+json'}

# %%
status, result = github_request(params=params,headers=headers, per_page=100, page=1, is_write=False)
# Out:
# requesting: https://api.github.com/repos/Jubatus/jubatus/subscribers?per_page=100&page=1
# total records of this request: 98

# %%
status
# Out:
# '200 OK'

# %% [markdown]
# # Retreive events and starring of sampled repository
# https://github-ranking.com/repositories

# %%
random.seed(586)
[random.randint(1,978) for i in range(1,11)]
# Out:
# [722, 115, 967, 361, 674, 469, 607, 386, 292, 112]

# %%
# owner, repo
repo_portfolio = [['lebinh', 'ngxtop'],
                  ['IanLunn', 'Hover'],
                  ['eczarny', 'spectacle'],
                  ['JakeWharton', 'ViewPagerIndicator'],
                  ['rendrjs', 'rendr'],
                  ['inconshreveable', 'ngrok'],
                  ['madebymany', 'sir-trevor-js'],
                  ['jschr', 'bootstrap-modal'],
                  ['carrierwaveuploader', 'carrierwave'],
                  ['jquery', 'jquery-ui']]

# %%
def dump_mongo(db_url, db_name, params, headers):
    mongocli = MongoClient(db_url)# init mongodb client
    mongodb = mongocli[db_name] # connect 'github' database
    
    page = 1
    collection_name = '.'.join(params)
    start_time = time.time()
    while True:
        status, json_body = github_request(params, headers,per_page=100,page=page)
        print 'page {} :'.format(page), 'status: ' + status + '\n'
        if status == '422 Unprocessable Entity' or len(json_body) == 0:
            break
        mongodb[collection_name].insert(json_body)
        page += 1
        time.sleep(1)
    mongocli.close() # close connection
    elapsed_time = time.time() - start_time
    print '------------------------------------'
    print 'completed: {}'.format(elapsed_time)

# %% [markdown]
# ### Retrieve events

# %%
events_list = [['repos'] + i + ['events'] for i in repo_portfolio]

# %%
db_url = 'ec2-54-67-97-244.us-west-1.compute.amazonaws.com:27017'
db_name = 'activities'
headers = {'Authorization' : 'token {}'.format(ACCESS_TOKEN)}

# %%
for event in events_list:
    print event
    dump_mongo(db_url,db_name,event,headers)
    print
# Out:
# requesting: https://api.github.com/repos/lebinh/ngxtop/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/events?per_page=100&page=3
# total records of this request: 0
# page 3 : status: 200 OK
#
# ------------------------------------
# completed: 6.11205482483
# requesting: https://api.github.com/repos/IanLunn/Hover/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/events?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 8.64627695084
# requesting: https://api.github.com/repos/eczarny/spectacle/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/events?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 10.052670002
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/events?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 7.50093197823
# requesting: https://api.github.com/repos/rendrjs/rendr/events?per_page=100&page=1
# total records of this request: 67
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/rendrjs/rendr/events?per_page=100&page=2
# total records of this request: 0
# page 2 : status: 200 OK
#
# ------------------------------------
# completed: 4.52781891823
# requesting: https://api.github.com/repos/inconshreveable/ngrok/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/inconshreveable/ngrok/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/inconshreveable/ngrok/events?per_page=100&page=3
# total records of this request: 96
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/inconshreveable/ngrok/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 8.42027401924
# requesting: https://api.github.com/repos/madebymany/sir-trevor-js/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/madebymany/sir-trevor-js/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/madebymany/sir-trevor-js/events?per_page=100&page=3
# total records of this request: 99
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/madebymany/sir-trevor-js/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 10.8610670567
# requesting: https://api.github.com/repos/jschr/bootstrap-modal/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/jschr/bootstrap-modal/events?per_page=100&page=2
# total records of this request: 60
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/jschr/bootstrap-modal/events?per_page=100&page=3
# total records of this request: 0
# page 3 : status: 200 OK
#
# ------------------------------------
# completed: 8.15883708
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/events?per_page=100&page=3
# total records of this request: 99
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 15.0152170658
# requesting: https://api.github.com/repos/jquery/jquery-ui/events?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/events?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/events?per_page=100&page=3
# total records of this request: 98
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/events?per_page=100&page=4
# total records of this request: 2
# page 4 : status: 422 Unprocessable Entity
#
# ------------------------------------
# completed: 14.0969769955

# %% [markdown]
# ### Retrieve starring

# %%
starring_list = [['repos'] + i + ['stargazers'] for i in repo_portfolio]

# %%
db_url = 'ec2-54-67-97-244.us-west-1.compute.amazonaws.com:27017'
db_name = 'activities'
headers = {'Authorization' : 'token {}'.format(ACCESS_TOKEN),'Accept' : 'application/vnd.github.v3.star+json'}

# %%
for starring in starring_list:
    print starring
    dump_mongo(db_url,db_name,starring,headers)
    print
# Out:
# ['repos', 'lebinh', 'ngxtop', 'stargazers']
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=4
# total records of this request: 100
# page 4 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=5
# total records of this request: 100
# page 5 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=6
# total records of this request: 100
# page 6 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=7
# total records of this request: 100
# page 7 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=8
# total records of this request: 100
# page 8 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=9
# total records of this request: 100
# page 9 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=10
# total records of this request: 100
# page 10 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=11
# total records of this request: 100
# page 11 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=12
# total records of this request: 100
# page 12 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=13
# total records of this request: 100
# page 13 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=14
# total records of this request: 100
# page 14 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=15
# total records of this request: 100
# page 15 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=16
# total records of this request: 100
# page 16 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=17
# total records of this request: 100
# page 17 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=18
# total records of this request: 100
# page 18 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=19
# total records of this request: 100
# page 19 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=20
# total records of this request: 100
# page 20 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=21
# total records of this request: 100
# page 21 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=22
# total records of this request: 100
# page 22 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=23
# total records of this request: 100
# page 23 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=24
# total records of this request: 100
# page 24 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=25
# total records of this request: 100
# page 25 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=26
# total records of this request: 100
# page 26 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=27
# total records of this request: 100
# page 27 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=28
# total records of this request: 100
# page 28 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=29
# total records of this request: 100
# page 29 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=30
# total records of this request: 100
# page 30 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=31
# total records of this request: 100
# page 31 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=32
# total records of this request: 100
# page 32 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=33
# total records of this request: 100
# page 33 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=34
# total records of this request: 100
# page 34 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=35
# total records of this request: 100
# page 35 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=36
# total records of this request: 100
# page 36 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=37
# total records of this request: 100
# page 37 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=38
# total records of this request: 100
# page 38 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=39
# total records of this request: 100
# page 39 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=40
# total records of this request: 100
# page 40 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=41
# total records of this request: 100
# page 41 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=42
# total records of this request: 43
# page 42 : status: 200 OK
#
# requesting: https://api.github.com/repos/lebinh/ngxtop/stargazers?per_page=100&page=43
# total records of this request: 0
# page 43 : status: 200 OK
#
# ------------------------------------
# completed: 80.5921831131
#
# ['repos', 'IanLunn', 'Hover', 'stargazers']
# requesting: https://api.github.com/repos/IanLunn/Hover/stargazers?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/stargazers?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/stargazers?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/stargazers?per_page=100&page=4
# total records of this request: 100
# page 4 : status: 200 OK
#
# requesting: https://api.github.com/repos/IanLunn/Hover/stargazers?per_page=100&page
: status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=12
# total records of this request: 100
# page 12 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=13
# total records of this request: 100
# page 13 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=14
# total records of this request: 100
# page 14 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=15
# total records of this request: 100
# page 15 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=16
# total records of this request: 100
# page 16 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=17
# total records of this request: 100
# page 17 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=18
# total records of this request: 100
# page 18 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=19
# total records of this request: 100
# page 19 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=20
# total records of this request: 100
# page 20 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=21
# total records of this request: 100
# page 21 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=22
# total records of this request: 100
# page 22 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=23
# total records of this request: 100
# page 23 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=24
# total records of this request: 100
# page 24 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=25
# total records of this request: 100
# page 25 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=26
# total records of this request: 100
# page 26 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=27
# total records of this request: 100
# page 27 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=28
# total records of this request: 100
# page 28 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=29
# total records of this request: 100
# page 29 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=30
# total records of this request: 100
# page 30 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=31
# total records of this request: 100
# page 31 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=32
# total records of this request: 100
# page 32 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=33
# total records of this request: 100
# page 33 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=34
# total records of this request: 100
# page 34 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=35
# total records of this request: 100
# page 35 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=36
# total records of this request: 100
# page 36 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=37
# total records of this request: 100
# page 37 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=38
# total records of this request: 100
# page 38 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=39
# total records of this request: 100
# page 39 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=40
# total records of this request: 100
# page 40 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=41
# total records of this request: 100
# page 41 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=42
# total records of this request: 100
# page 42 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=43
# total records of this request: 100
# page 43 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=44
# total records of this request: 100
# page 44 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=45
# total records of this request: 100
# page 45 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=46
# total records of this request: 100
# page 46 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=47
# total records of this request: 100
# page 47 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=48
# total records of this request: 100
# page 48 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=49
# total records of this request: 100
# page 49 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=50
# total records of this request: 100
# page 50 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=51
# total records of this request: 100
# page 51 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=52
# total records of this request: 100
# page 52 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=53
# total records of this request: 100
# page 53 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=54
# total records of this request: 100
# page 54 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=55
# total records of this request: 100
# page 55 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=56
# total records of this request: 100
# page 56 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=57
# total records of this request: 100
# page 57 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=58
# total records of this request: 100
# page 58 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=59
# total records of this request: 100
# page 59 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=60
# total records of this request: 100
# page 60 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=61
# total records of this request: 100
# page 61 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=62
# total records of this request: 100
# page 62 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=63
# total records of this request: 82
# page 63 : status: 200 OK
#
# requesting: https://api.github.com/repos/eczarny/spectacle/stargazers?per_page=100&page=64
# total records of this request: 0
# page 64 : status: 200 OK
#
# ------------------------------------
# completed: 127.805747986
#
# ['repos', 'JakeWharton', 'ViewPagerIndicator', 'stargazers']
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=4
# total records of this request: 100
# page 4 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=5
# total records of this request: 100
# page 5 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=6
# total records of this request: 100
# page 6 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=7
# total records of this request: 100
# page 7 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=8
# total records of this request: 100
# page 8 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=9
# total records of this request: 100
# page 9 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=10
# total records of this request: 100
# page 10 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=11
# total records of this request: 100
# page 11 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=12
# total records of this request: 100
# page 12 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=13
# total records of this request: 100
# page 13 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=14
# total records of this request: 100
# page 14 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=15
# total records of this request: 100
# page 15 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=16
# total records of this request: 100
# page 16 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=17
# total records of this request: 100
# page 17 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=18
# total records of this request: 100
# page 18 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=19
# total records of this request: 100
# page 19 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=20
# total records of this request: 100
# page 20 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=21
# total records of this request: 100
# page 21 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=22
# total records of this request: 100
# page 22 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=23
# total records of this request: 100
# page 23 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=24
# total records of this request: 100
# page 24 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=25
# total records of this request: 100
# page 25 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=26
# total records of this request: 100
# page 26 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=27
# total records of this request: 100
# page 27 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=28
# total records of this request: 100
# page 28 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=29
# total records of this request: 100
# page 29 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=30
# total records of this request: 100
# page 30 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=31
# total records of this request: 100
# page 31 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=32
# total records of this request: 100
# page 32 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=33
# total records of this request: 100
# page 33 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=34
# total records of this request: 100
# page 34 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=35
# total records of this request: 100
# page 35 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=36
# total records of this request: 100
# page 36 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=37
# total records of this request: 100
# page 37 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=38
# total records of this request: 100
# page 38 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=39
# total records of this request: 100
# page 39 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=40
# total records of this request: 100
# page 40 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=41
# total records of this request: 100
# page 41 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=42
# total records of this request: 100
# page 42 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=43
# total records of this request: 100
# page 43 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=44
# total records of this request: 100
# page 44 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=45
# total records of this request: 100
# page 45 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=46
# total records of this request: 100
# page 46 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=47
# total records of this request: 100
# page 47 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=48
# total records of this request: 100
# page 48 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=49
# total records of this request: 100
# page 49 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=50
# total records of this request: 100
# page 50 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=51
# total records of this request: 100
# page 51 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=52
# total records of this request: 100
# page 52 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=53
# total records of this request: 100
# page 53 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=54
# total records of this request: 100
# page 54 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=55
# total records of this request: 100
# page 55 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=56
# total records of this request: 100
# page 56 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=57
# total records of this request: 100
# page 57 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=58
# total records of this request: 100
# page 58 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=59
# total records of this request: 100
# page 59 : status: 200 OK
#
# requesting: https://api.github.com/repos/JakeWharton/ViewPagerIndicator/stargazers?per_page=100&page=60
# total records of this request: 100
# page 60 : status: 200 OK
#
# ...
# page 65 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/stargazers?per_page=100&page=66
# total records of this request: 100
# page 66 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/stargazers?per_page=100&page=67
# total records of this request: 100
# page 67 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/stargazers?per_page=100&page=68
# total records of this request: 100
# page 68 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/stargazers?per_page=100&page=69
# total records of this request: 100
# page 69 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/stargazers?per_page=100&page=70
# total records of this request: 55
# page 70 : status: 200 OK
#
# requesting: https://api.github.com/repos/carrierwaveuploader/carrierwave/stargazers?per_page=100&page=71
# total records of this request: 0
# page 71 : status: 200 OK
#
# ------------------------------------
# completed: 153.504631996
#
# ['repos', 'jquery', 'jquery-ui', 'stargazers']
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=1
# total records of this request: 100
# page 1 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=2
# total records of this request: 100
# page 2 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=3
# total records of this request: 100
# page 3 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=4
# total records of this request: 100
# page 4 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=5
# total records of this request: 100
# page 5 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=6
# total records of this request: 100
# page 6 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=7
# total records of this request: 100
# page 7 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=8
# total records of this request: 100
# page 8 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=9
# total records of this request: 100
# page 9 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=10
# total records of this request: 100
# page 10 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=11
# total records of this request: 100
# page 11 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=12
# total records of this request: 100
# page 12 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=13
# total records of this request: 100
# page 13 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=14
# total records of this request: 100
# page 14 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=15
# total records of this request: 100
# page 15 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=16
# total records of this request: 100
# page 16 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=17
# total records of this request: 100
# page 17 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=18
# total records of this request: 100
# page 18 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=19
# total records of this request: 100
# page 19 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=20
# total records of this request: 100
# page 20 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=21
# total records of this request: 100
# page 21 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=22
# total records of this request: 100
# page 22 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=23
# total records of this request: 100
# page 23 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=24
# total records of this request: 100
# page 24 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=25
# total records of this request: 100
# page 25 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=26
# total records of this request: 100
# page 26 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=27
# total records of this request: 100
# page 27 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=28
# total records of this request: 100
# page 28 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=29
# total records of this request: 100
# page 29 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=30
# total records of this request: 100
# page 30 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=31
# total records of this request: 100
# page 31 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=32
# total records of this request: 100
# page 32 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=33
# total records of this request: 100
# page 33 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=34
# total records of this request: 100
# page 34 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=35
# total records of this request: 100
# page 35 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=36
# total records of this request: 100
# page 36 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=37
# total records of this request: 100
# page 37 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=38
# total records of this request: 100
# page 38 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=39
# total records of this request: 100
# page 39 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=40
# total records of this request: 100
# page 40 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=41
# total records of this request: 100
# page 41 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=42
# total records of this request: 100
# page 42 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=43
# total records of this request: 100
# page 43 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=44
# total records of this request: 100
# page 44 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=45
# total records of this request: 100
# page 45 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=46
# total records of this request: 100
# page 46 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=47
# total records of this request: 100
# page 47 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=48
# total records of this request: 100
# page 48 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=49
# total records of this request: 100
# page 49 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=50
# total records of this request: 100
# page 50 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=51
# total records of this request: 100
# page 51 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=52
# total records of this request: 100
# page 52 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=53
# total records of this request: 100
# page 53 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=54
# total records of this request: 100
# page 54 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=55
# total records of this request: 100
# page 55 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=56
# total records of this request: 100
# page 56 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=57
# total records of this request: 100
# page 57 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=58
# total records of this request: 100
# page 58 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=59
# total records of this request: 100
# page 59 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=60
# total records of this request: 100
# page 60 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=61
# total records of this request: 100
# page 61 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=62
# total records of this request: 100
# page 62 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=63
# total records of this request: 100
# page 63 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=64
# total records of this request: 100
# page 64 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=65
# total records of this request: 100
# page 65 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=66
# total records of this request: 100
# page 66 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=67
# total records of this request: 100
# page 67 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=68
# total records of this request: 100
# page 68 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=69
# total records of this request: 100
# page 69 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=70
# total records of this request: 100
# page 70 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=71
# total records of this request: 100
# page 71 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=72
# total records of this request: 100
# page 72 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=73
# total records of this request: 100
# page 73 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=74
# total records of this request: 100
# page 74 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=75
# total records of this request: 100
# page 75 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=76
# total records of this request: 100
# page 76 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=77
# total records of this request: 100
# page 77 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=78
# total records of this request: 100
# page 78 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=79
# total records of this request: 100
# page 79 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=80
# total records of this request: 100
# page 80 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=81
# total records of this request: 100
# page 81 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=82
# total records of this request: 100
# page 82 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=83
# total records of this request: 100
# page 83 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=84
# total records of this request: 100
# page 84 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=85
# total records of this request: 100
# page 85 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=86
# total records of this request: 100
# page 86 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=87
# total records of this request: 100
# page 87 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=88
# total records of this request: 100
# page 88 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=89
# total records of this request: 100
# page 89 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=90
# total records of this request: 100
# page 90 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=91
# total records of this request: 100
# page 91 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=92
# total records of this request: 100
# page 92 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=93
# total records of this request: 100
# page 93 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=94
# total records of this request: 100
# page 94 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=95
# total records of this request: 100
# page 95 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=96
# total records of this request: 100
# page 96 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=97
# total records of this request: 55
# page 97 : status: 200 OK
#
# requesting: https://api.github.com/repos/jquery/jquery-ui/stargazers?per_page=100&page=98
# total records of this request: 0
# page 98 : status: 200 OK
#
# ------------------------------------
# completed: 195.115231991
